# %% [markdown]
# <a href="https://colab.research.google.com/github/olanigan/huggingface_labs/blob/main/distil_whisper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Setup Environment

# %%
# !pip install -q transformers
#!pip install llama-index  accelerate bitsandbytes
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 30.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 83.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 18.4 MB/s eta 0:00:00

# %% [markdown]
# ## Load Pipeline

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("automatic-speech-recognition", model="distil-whisper/distil-medium.en")
# Out:
# ...
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# ...

# %% [markdown]
# ## Transcribe Audio

# %%
results = pipe("audio.m4a")
#30s audio transcribed in 28s

# %%
results
# Out:
# {'text': " There is one iOS 17 feature that I have personal beef with because it gets accidentally triggered all the time and it's a feature that lets you share contact information just by bumping two iPhones together so I'm going to show you how to turn that off. So you're going to go into your settings and then go to general and then tap air drop and where it says bringing devices together you're going to want to hit that toggle to turn it off. So now if you have two phones like a personal phone and a work phone you won't have to worry about them trying to share information whenever they touch."}

# %%
results = pipe("audio.mp3")
#57m transcribed in 39s

# %%
len(results['text'])
# Out:
# 63

# %%
results
# Out:
# {'text': " I'm not going to know what I'm going to be in a minute of him."}
